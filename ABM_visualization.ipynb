# %% [markdown]
# ## Strategies
#
# - random
#
# - fixed(Spock)
#
# - copy
#
# - adaptive (long memory)
#
# - try-to-lose (reverse_adaptive) (long memory)
#
# ### Basic Comparison
#
# - random
#
#     - random vs fixed(Spock)
#
#     - random vs copy
#
#     - random vs adaptive
#
#     - random vs try-to-lose
#
# - fixed(Spock)
#
#     - fixed vs copy
#
#     - fixed vs adaptive
#
#     - fixed vs try-to-lose
#
# - copy
#
#     - copy vs adaptive
#
#     - copy vs try-to-lose
#
# - adaptive
#
#     - adaptive vs try-to-lose
#
# ### Additional combinations
#
# - random vs fixed (for each move)
#
# - long/short memory of adaptive
#
# ### If interesting
#
# - Fixed_high_payoff vs Fixed_low_payoff
#
# ### If time allows
#
# - Q-learning

# %% [markdown]
# ## Simulation Settings
#
# - for each strategies combination: 100 times of simulation (games will repeat 100 times )
#
# - For each game: 1000 rounds

# %% [markdown]
# ## Standard of Comparison btwn the Strategies
#
# 1. Winning Rate
#
# 2. Mean, Variance of scores of two players

# %% [markdown]
# ## Main Findings
#
# - random vs fixed (for each move)
#     - Expected(points)
#
# - long/short memory of adaptive
#     - history of each rounds
#     - frequency of each moves of two players (For each player, they should switch btwn two moves)

# %% [markdown]
# ## Visualization of Standard of Comparison btwn the Strategies
#
# 1. bar chart: winning rate (10 combinations in one graph) to see whether the strategy is efficient
#
# 2. line chart: score difference through out 100 times to see whether the strategy is stable (10 graphs)
#
#     - also plot mean of score difference (horizontal line)
#
# Example of the line chart(2.): score difference through out 100 times, random vs fixed(Spock)
# ![image.png](attachment:image.png)
#
#
# ## Visualization of Main Findings
#
# ### Random vs Each Fixed Strategy
#
# 3. line and dot chart: take one simulation (1 time game) (5 graphs)
#
#     - plot the expected points line (theoretical)
#
#     - plot the points actually gain in the game
#
#
#         For example, Random vs Spock
#
#         $ y = 0 $ (fixed)
#
#
#         $ y = (-3 \cdot \frac{1}{5} + 2 \cdot \frac{1}{5} + (-1) \cdot \frac{1}{5} + 4 \cdot \frac{1}{5} + 0 \cdot \frac{1}{5}) \times x $ (theoretical)
#
#         Actual Cummulative Points $(x_i, y_i)$
#
#         where x is the number of rounds, y is the points
#
#
# ### Long/Short Memory in Adaptive Strategies
#
# 4. Heat Maps: Use heat maps to represent the frequency of moves made by players using long vs. short memory adaptive strategies. To visualize patterns and changes in strategy over time.
#
# 5. Time-Series Plot: Show how the frequency of moves or strategies changes over the course of 1000 rounds. To highlight the adaptation process and how quickly one strategy outpaces another in terms of adjustment.

# %% [markdown]
# ### If Fixed_high_payoff vs Fixed_low_payoff and Q-learning
#
# Please run the simulations and find out appropriate graphs to explore different aspects of the game outcomes.
